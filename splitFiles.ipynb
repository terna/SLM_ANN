# %%
import csv

textIn=[]
textOu=[]
translator={}

with open("textExamples.txt", newline='') as csvfile:
    reader= csv.reader(csvfile, delimiter=',')#, quoting=csv.QUOTE_NONNUMERIC)
    
    for row in reader:
        index = row.index('>')
        print(row, index)
        textIn.append(list(row[i] for i in range(index)))
        textOu.append(list(row[i] for i in range(index+1,len(row)))) #len(row) is exceeding the last word position

print(textIn)
print(textOu)

with open("textCoding.txt", newline='') as csvfile:
    reader= csv.reader(csvfile, delimiter=',')#, quoting=csv.QUOTE_NONNUMERIC)
    
    for row in reader:
        print(row)
        translator[row[0]] = int(row[1])
    translator[' ']=0

print("dictionary\n",translator)

for i in range(len(textIn)):
    for j in range(len(textIn[i])):
        textIn[i][j]=translator[textIn[i][j]]
    for j in range(len(textOu[i])):
        textOu[i][j]=translator[textOu[i][j]]


print("In\n",textIn)
print("Ou\n",textOu)

#scale and complete
for i in range(len(textIn)):
    for j in range(len(textIn[i])):
        textIn[i][j] /= 16
    while len(textIn[i]) < 3: 
        textIn[i].append(0)
    for j in range(len(textOu[i])):
        textOu[i][j] /= 16
    while len(textOu[i]) < 2: 
        textOu[i].append(0)

print("In\n",textIn)
print("Ou\n",textOu)

with open("in.txt", mode='w', newline='') as csvfile1:
    for i in range(len(textIn)):
        print(f"{textIn[i][0]},{textIn[i][1]},{textIn[i][2]}", file=csvfile1)
                       
with open("ou.txt", mode='w', newline='') as csvfile2:
    for i in range(len(textOu)):
        print(f"{textOu[i][0]},{textOu[i][1]}", file=csvfile2)
# Out:
# ['il', 'gatto', 'mangia', '>', 'il', 'topo'] 3
# ['il', 'gatto', '>', 'miagola'] 2
# ['il', 'cane', 'mangia', '>', 'il', 'gatto'] 3
# ['il', 'cane', '>', 'abbaia'] 2
# ['il', 'topo', 'mangia', '>', 'il', 'formaggio'] 3
# ['il', 'bimbo', 'chiama', '>', 'la', 'mamma'] 3
# ['il', 'bimbo', 'mangia', '>', 'la', 'pappa'] 3
# ['il', 'bimbo', '>', 'piange'] 2
# ['bimbo', 'e', 'gatto', '>', 'giocano'] 3
# [['il', 'gatto', 'mangia'], ['il', 'gatto'], ['il', 'cane', 'mangia'], ['il', 'cane'], ['il', 'topo', 'mangia'], ['il', 'bimbo', 'chiama'], ['il', 'bimbo', 'mangia'], ['il', 'bimbo'], ['bimbo', 'e', 'gatto']]
# [['il', 'topo'], ['miagola'], ['il', 'gatto'], ['abbaia'], ['il', 'formaggio'], ['la', 'mamma'], ['la', 'pappa'], ['piange'], ['giocano']]
# ['il', '1']
# ['gatto', '2']
# ['mangia', '3']
# ['topo', '4']
# ['miagola', '5']
# ['cane', '6']
# ['abbaia', '7']
# ['formaggio', '8']
# ['bimbo', '9']
# ['chiama', '10']
# ['la', '11']
# ['mamma', '12']
# ['pappa', '13']
# ['piange', '14']
# ['e', '15']
# ['giocano', '16']
# dictionary
#  {'il': 1, 'gatto': 2, 'mangia': 3, 'topo': 4, 'miagola': 5, 'cane': 6, 'abbaia': 7, 'formaggio': 8, 'bimbo': 9, 'chiama': 10, 'la': 11, 'mamma': 12, 'pappa': 13, 'piange': 14, 'e': 15, 'giocano': 16, ' ': 0}
# In
#  [[1, 2, 3], [1, 2], [1, 6, 3], [1, 6], [1, 4, 3], [1, 9, 10], [1, 9, 3], [1, 9], [9, 15, 2]]
# Ou
#  [[1, 4], [5], [1, 2], [7], [1, 8], [11, 12], [11, 13], [14], [16]]
# In
#  [[0.0625, 0.125, 0.1875], [0.0625, 0.125, 0], [0.0625, 0.375, 0.1875], [0.0625, 0.375, 0], [0.0625, 0.25, 0.1875], [0.0625, 0.5625, 0.625], [0.0625, 0.5625, 0.1875], [0.0625, 0.5625, 0], [0.5625, 0.9375, 0.125]]
# Ou
#  [[0.0625, 0.25], [0.3125, 0], [0.0625, 0.125], [0.4375, 0], [0.0625, 0.5], [0.6875, 0.75], [0.6875, 0.8125], [0.875, 0], [1.0, 0]]

# %% [markdown]
# Database
#
# il,gatto,mangia,>,il,topo
# il,gatto,>,miagola
# il,cane,mangia,>,il,gatto
# il,cane,>,abbaia
# il,topo,mangia,>,il,formaggio
# il,bimbo,chiama,>,la,mamma
# il,bimbo,mangia,>,la,pappa
# il,bimbo,>,piange
# bimbo,e,gatto,>,giocano
#
# 0 as empty position
